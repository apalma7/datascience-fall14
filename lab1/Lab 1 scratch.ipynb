# %%
import numpy as np

X = np.random.random((2,6))

print X
# Out:
# [[ 0.74318547  0.07815141  0.15286748  0.16337591  0.17918465  0.82805373]
#  [ 0.59702809  0.77417498  0.41567451  0.30006824  0.48580887  0.1509911 ]]

# %%
print X[0,0]
# Out:
# 0.743185469096

# %%
print X[:, 1]
# Out:
# [ 0.07815141  0.77417498]

# %%
print X.T
# Out:
# [[ 0.74318547  0.59702809]
#  [ 0.07815141  0.77417498]
#  [ 0.15286748  0.41567451]
#  [ 0.16337591  0.30006824]
#  [ 0.17918465  0.48580887]
#  [ 0.82805373  0.1509911 ]]

# %%
print X**-1
# Out:
# [[  1.34555914  12.79567422   6.54161353   6.12085338   5.58083506
#     1.2076511 ]
#  [  1.67496306   1.29169765   2.40572844   3.33257525   2.05842269
#     6.62290687]]

# %%
# %pylab inline
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
X = np.linspace(0, 10, 2000)
y = np.sin(X)
plt.plot(X, y)

# %%
X = np.random.normal(size = 300)
y = np.random.normal(size = 300)
plt.scatter(X, y)

# %%
X = np.linspace(1, 12, 100)
y = X[:, np.newaxis]
im = y * np.sin(X) * np.cos(y)

im = y * np.sin(X) * np.cos(y)

plt.imshow(im)

# %%
plt.contour(im)
# Out:
# <matplotlib.contour.QuadContourSet instance at 0xb1251a8c>

# %%
from sklearn.datasets import load_iris
iris = load_iris()
print iris.keys()
# Out:
# ['target_names', 'data', 'target', 'DESCR', 'feature_names']

# %%
n_samples, n_features = iris.data.shape
print 'Number of samples = ', n_samples
print 'Number of features = ', n_features
# Out:
# Number of samples =  150
# Number of features =  4

# %%
Samples = [0, 50, 6, 100, 10, 20]
for i in Samples:
    sample_features = iris.data[i]
    sample_class_index = iris.target[i]
    sample_class_name = iris.target_names[sample_class_index]
    print sample_features, sample_class_name
# Out:
# [ 5.1  3.5  1.4  0.2] setosa
# [ 7.   3.2  4.7  1.4] versicolor
# [ 4.6  3.4  1.4  0.3] setosa
# [ 6.3  3.3  6.   2.5] virginica
# [ 5.4  3.7  1.5  0.2] setosa
# [ 5.4  3.4  1.7  0.2] setosa

# %%
boston = sklearn.datasets.load_boston()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-639333e529fd> in <module>()
# ----> 1 boston = sklearn.datasets.load_boston()
#
# NameError: name 'sklearn' is not defined

# %%
print iris.feature_names
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']

# %%
iris.DESCR.CRIM
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-bf42a4d96521> in <module>()
# ----> 1 iris.DESCR.CRIM
#
# AttributeError: 'str' object has no attribute 'CRIM'

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
print iris.data[50]
print iris.target[50]
# Out:
# [ 7.   3.2  4.7  1.4]
# 1

# %%
#The total number of records in a feature
total_data = boston.data.shape[0]
#The values belowe represent the P% of the data (for instance boston_20_X represents 20% of the data).
#Each value has a corresponding compliment value such that together they reprsent 100% of the data.
#For example, boston_20_X reprsents the top 20% of the data and boston_80_X represents the bottom 80%.
boston_20_X = boston.data[math.floor(.2*total_data):]
boston_80_X = boston.data[:math.ceil(.8*total_data)]
boston_40_X = boston.data[math.floor(.4*total_data):]
boston_60_X = boston.data[:math.ceil(.6*total_data)]

boston_20_y = boston.target[math.floor(.2*total_data):]
boston_80_y = boston.target[:math.ceil(.8*total_data)]
boston_40_y = boston.target[math.floor(.4*total_data):]
boston_60_y = boston.target[:math.ceil(.6*total_data)]


regr_20 = LinearRegression()
regr_40 = LinearRegression()
regr_60 = LinearRegression()
regr_80 = LinearRegression()

regr_20.fit(boston_20_X, boston_20_y)
regr_40.fit(boston_40_X, boston_40_y)
regr_60.fit(boston_60_X, boston_60_y)
regr_80.fit(boston_80_X, boston_80_y)

predicted_20 = regr_20.predict(boston_80_X)
predicted_40 = regr_40.predict(boston_60_X)
predicted_60 = regr_60.predict(boston_40_X)
predicted_80 = regr_80.predict(boston_20_X)

mse_func = lambda predicted, y: np.mean((predicted - y) ** 2)
mses = [mse_func(predicted_20, boston_80_y), mse_func(predicted_40, boston_60_y), mse_func(predicted_60, boston_40_y), mse_func(predicted_80, boston_20_y)]
barx = [20, 40, 60, 80]

plt.bar(barx, mses, width=5, align='center')
plt.show()
